# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth

sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id="0f9ff4fa8f8e477cb75c8ca442654dfb",
                                               client_secret="17d823821d024ed6b301a93c7e0e85c8",
                                               redirect_uri="http://127.0.0.1:9090",
                                               scope="user-library-read user-read-recently-played"))

# %%
# Get your recently played tracks
results = sp.current_user_recently_played(limit=20)  # Get the 20 most recent tracks

# Print each track with its artist and when it was played
for item in results['items']:
    track = item['track']
    artists = ', '.join([artist['name'] for artist in track['artists']])
    played_at = item['played_at']
    print(f"Track: {track['name']}")
    print(f"Artist(s): {artists}")
    print(f"Played at: {played_at}")
    print(f"Track ID: {track['id']}")

    print("-" * 50)
# Out:
# Track: My Old Ways
# Artist(s): Tame Impala
# Played at: 2025-10-21T13:22:50.449Z
# Track ID: 4whkhyXTrTgHKZzkUvdwoq
# --------------------------------------------------

# %%
import pandas as pd

chosic_data = pd.read_csv("Chosic test.csv")
chosic_data.head()
# Out:
#    #         Song       Artist  Popularity  BPM                  Genres  \
# 0  1  My Old Ways  Tame Impala          81  110  neo-psychedelic, indie
# 1  2   Plain Jane    A$AP Ferg          68  170                     rap
#
#   Parent Genres           Album  Album Date   Time  ...  Speech  Live  \
# 0     Pop, Rock        Deadbeat  2025-10-17  04:58  ...       0    30
# 1       Hip Hop  Still Striving  2017-08-18  02:53  ...      20     0
#
#    Loud (Db)          Key  Time Signature    Added At        Spotify Track Id  \
# 0         -6  A#/B♭ minor               4  2025-10-27  4whkhyXTrTgHKZzkUvdwoq
# 1         -5            B               4  2025-10-27  4dVpf9jZjcORqGTLUaeYj9
#
#          Album Label Camelot          ISRC
# 0           Columbia      3A  USQX92504221
# 1  RCA Records Label      1B  USRC11701803
#
# [2 rows x 25 columns]
